# %%
import cv2
import smtplib

email_limit = 3
email_count = 0

def send_email(subject, body):
    global email_count, email_limit

    message = f"Subject: {subject}\n\n{body}"

    try:
        with smtplib.SMTP(smtp_server, smtp_port) as server:
            server.starttls()
            server.login(sender_email, sender_password)
            server.sendmail(sender_email, receiver_email, message)
        print("Email sent successfully!")

     
        email_count += 1
        if email_count >= email_limit:
            print("Email limit reached. Stopping the program.")
            exit(0)
    except Exception as e:
        
        print("Failed to send email:", str(e))






def send_email(subject, body):
    global email_count, email_limit

    message = f"Subject: {subject}\n\n{body}"

    try:
        with smtplib.SMTP(smtp_server, smtp_port) as server:
            server.starttls()
            server.login(sender_email, sender_password)
            server.sendmail(sender_email, receiver_email, message)
        print("Email sent successfully!")

        # Increment the email count
        email_count += 1
        if email_count >= email_limit:
            print("Email limit reached. Stopping the program.")
            exit(0)
    except Exception as e:
        print("Failed to send email:", str(e))


def detect_faces():
    face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")
    cap = cv2.VideoCapture(0)  # Use 0 for the default camera, or a video file path if desired.

    while True:
        ret, frame = cap.read()
        if not ret:
            print("Error reading frame.")
            break

        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))
        if not face_detected and len(faces) > 0:
            for (x, y, w, h) in faces:

                cv2.rectangle(frame, (x, y), (x + w, y + h), (255, 0, 0), 2)

            subject = "Face Detected!"
            body = "A face has been detected. Check the camera feed for more details."
            send_email(subject, body)

        cv2.imshow('Face Detection', frame)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()

detect_faces()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12452\3947241531.py in <module>
#      81     cv2.destroyAllWindows()
#      82
# ---> 83 detect_faces()
#
# ~\AppData\Local\Temp\ipykernel_12452\3947241531.py in detect_faces()
#      64         gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#      65         faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))
# ---> 66         if not face_detected and len(faces) > 0:
#      67             for (x, y, w, h) in faces:
#      68
#
# NameError: name 'face_detected' is not defined
